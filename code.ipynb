# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import when
from pyspark.sql.functions import sum,avg,max,count

# %%
spark = SparkSession.builder.master("local[*]").appName("Datamanipulation").getOrCreate()

# %%
df = spark.read.table("sample___eu_superstore_1_csv")

# %%
data = df.filter(df["Country"] == "France")
data.count()
# Out:
# Out[19]: 2827

# %%
data.filter(df["Profit"] > 0).count()
# Out:
# Out[20]: 2329

# %%
dis_set = df.select(["Discount"]).distinct()
dis_set.count()
dis_set.show()
# Out:
# +--------+
# |Discount|
# +--------+
# |    null|
# |       0|
# +--------+

# %%
df.groupBy("Discount").agg({'Profit': 'sum'}).orderBy('sum(Profit)').show()
# Out:
# +--------+------------------+
# |Discount|       sum(Profit)|
# +--------+------------------+
# |    null|-10976.78881773213|
# |       0| 383806.5302368067|
# +--------+------------------+

# %%
cust_profit = df.groupBy(["Customer ID","Customer Name"]).agg({'Profit': 'sum'}).orderBy('Sum(Profit)',ascending = False)
cust_profit.show(5)
# Out:
# +-----------+-----------------+------------------+
# |Customer ID|    Customer Name|       sum(Profit)|
# +-----------+-----------------+------------------+
# |   SP-20920|     Susan Pistek| 4974.513064682484|
# |   PJ-18835|    Patrick Jones|3986.0040826797485|
# |   PO-18865|Patrick O'Donnell| 3778.197093129158|
# |   EB-13840|    Ellis Ballard| 3459.660038240254|
# |   MG-18145|  Mike Gockenbach|3144.4440593719482|
# +-----------+-----------------+------------------+
# only showing top 5 rows

# %%
cust_profit.collect()
# Out:
# Out[24]: [Row(Customer ID='SP-20920', Customer Name='Susan Pistek', sum(Profit)=4974.513064682484),
#  Row(Customer ID='PJ-18835', Customer Name='Patrick Jones', sum(Profit)=3986.0040826797485),
#  Row(Customer ID='PO-18865', Customer Name="Patrick O'Donnell", sum(Profit)=3778.197093129158),
#  Row(Customer ID='EB-13840', Customer Name='Ellis Ballard', sum(Profit)=3459.660038240254),
#  Row(Customer ID='MG-18145', Customer Name='Mike Gockenbach', sum(Profit)=3144.4440593719482),
#  Row(Customer ID='ER-13855', Customer Name='Elpida Rittenbach', sum(Profit)=2899.805934727192),
#  Row(Customer ID='LB-16795', Customer Name='Laurel Beltran', sum(Profit)=2892.717029929161),
#  Row(Customer ID='RB-19330', Customer Name='Randy Bradley', sum(Profit)=2864.600984307006),
#  Row(Customer ID='JH-15820', Customer Name='John Huston', sum(Profit)=2860.1025133132935),
#  Row(Customer ID='MS-17770', Customer Name='Maxwell Schwartz', sum(Profit)=2795.8799901008606),
#  Row(Customer ID='BV-11245', Customer Name='Benjamin Venier', sum(Profit)=2761.271975040436),
#  Row(Customer ID='JB-16000', Customer Name='Joy Bell-', sum(Profit)=2754.179962158203),
#  Row(Customer ID='ON-18715', Customer Name='Odella Nelson', sum(Profit)=2732.036996314302),
#  Row(Customer ID='KN-16390', Customer Name='Katherine Nockton', sum(Profit)=2729.576997756958),
#  Row(Customer ID='JG-15160', Customer Name='James Galang', sum(Profit)=2718.72593665123),
#  Row(Customer ID='HM-14860', Customer Name='Harry Marie', sum(Profit)=2385.4049993753433),
#  Row(Customer ID='AM-10360', Customer Name='Alice McCarthy', sum(Profit)=2375.5019533485174),
#  Row(Customer ID='DL-13315', Customer Name='Delfina Latchford', sum(Profit)=2243.464456319809),
#  Row(Customer ID='EB-14110', Customer Name='Eugene Barchas', sum(Profit)=2169.0420414209366),
#  Row(Customer ID='SE-20110', Customer Name='Sanjit Engle', sum(Profit)=2139.3990354537964),
#  Row(Customer ID='VP-21760', Customer Name='Victoria Pisteka', sum(Profit)=2056.299020051956),
#  Row(Customer ID='AR-10825', Customer Name='Anthony Rawles', sum(Profit)=1978.1700036525726),
#  Row(Customer ID='BP-11155', Customer Name='Becky Pak', sum(Profit)=1971.9209430217743),
#  Row(Customer ID='CW-11905', Customer Name='Carl Weiss', sum(Profit)=1956.3509874343872),
#  Row(Customer ID='KC-16675', Customer Name='Kimberly Carter', sum(Profit)=1941.8670105934143),
#  Row(Customer ID='RA-19285', Customer Name='Ralph Arnett', sum(Profit)=1934.3010199069977),
#  Row(Customer ID='MM-18055', Customer Name='Michelle Moray', sum(Profit)=1930.4580047130585),
#  Row(Customer ID='BH-11710', Customer Name='Brosina Hoffman', sum(Profit)=1928.6760030984879),
#  Row(Customer ID='DK-13090', Customer Name='Dave Kipp', sum(Profit)=1927.2840127944946),
#  Row(Customer ID='CM-11830', Customer Name='Cari MacIntyre', sum(Profit)=1844.32351064682),
#  Row(Customer ID='EM-14065', Customer Name='Erin Mull', sum(Profit)=1837.3319633603096),
#  Row(Customer ID='BE-11410', Customer Name='Bobby Elias', sum(Profit)=1821.6870222091675),
#  Row(Customer ID='TZ-21580', Customer Name='Tracy Zic', sum(Profit)=1809.2160604000092),
#  Row(Customer ID='AM-10705', Customer Name='Anne McFarland', sum(Profit)=1797.753032386303),
#  Row(Customer ID='JW-16075', Customer Name='Julia West', sum(Profit)=1732.711497426033),
#  Row(Customer ID='NF-18475', Customer Name='Neil Französisch', sum(Profit)=1728.9059994854033),
#  Row(Customer ID='PO-18850', Customer Name="Patrick O'Brill", sum(Profit)=1708.3710230588913),
#  Row(Customer ID='RF-19840', Customer Name='Roy Französisch', sum(Profit)=1701.6060206890106),
#  Row(Customer ID='LT-16765', Customer Name='Larry Tron', sum(Profit)=1701.3254640102386),
#  Row(Customer ID='BW-11110', Customer Name='Bart Watters', sum(Profit)=1686.2220368385315),
#  Row(Customer ID='AG-10495', Customer Name='Andrew Gjertsen', sum(Profit)=1669.552483201027),
#  Row(Customer ID='CB-12415', Customer Name='Christy Brittain', sum(Profit)=1653.7680305242538),
#  Row(Customer ID='TH-21100', Customer Name='Thea Hendricks', sum(Profit)=1603.5270190238953),
#  Row(Customer ID='JB-15400', Customer Name='Jennifer Braxton', sum(Profit)=1598.8275413513184),
#  Row(Customer ID='EM-14095', Customer Name='Eudokia Martin', sum(Profit)=1582.48202419281),
#  Row(Customer ID='SC-20095', Customer Name='Sanjit Chand', sum(Profit)=1572.0569489002228),
#  Row(Customer ID='AT-10435', Customer Name='Alyssa Tate', sum(Profit)=1570.7880010604858),
#  Row(Customer ID='BC-11125', Customer Name='Becky Castell', sum(Profit)=1567.0409908890724),
#  Row(Customer ID='YC-21895', Customer Name='Yoseph Carroll', sum(Profit)=1556.4584952779114),
#  Row(Customer ID='DK-12835', Customer Name='Damala Kotsonis', sum(Profit)=1549.8299658298492),
#  Row(Customer ID='FO-14305', Customer Name='Frank Olsen', sum(Profit)=1542.98698502779),
#  Row(Customer ID='CA-12265', Customer Name='Christina Anderson', sum(Profit)=1505.3925094604492),
#  Row(Customer ID='MW-18220', Customer Name='Mitch Webber', sum(Profit)=1505.157015323639),
#  Row(Customer ID='KD-16495', Customer Name='Keith Dawkins', sum(Profit)=1496.4675296545029),
#  Row(Customer ID='TH-21235', Customer Name='Tiffany House', sum(Profit)=1493.6850564479828),
#  Row(Customer ID='BE-11335', Customer Name='Bill Eplett', sum(Profit)=1488.3329691886902),
#  Row(Customer ID='BT-11395', Customer Name='Bill Tyler', sum(Profit)=1481.3070015907288),
#  Row(Customer ID='AH-10210', Customer Name='Alan Hwang', sum(Profit)=1478.2785029411316),
#  Row(Customer ID='JF-15565', Customer Name='Jill Fjeld', sum(Profit)=1471.736968755722),
#  Row(Customer ID='CK-12205', Customer Name='Chloris Kastensmidt', sum(Profit)=1464.4919600486755),
#  Row(Customer ID='JP-15520', Customer Name='Jeremy Pistek', sum(Profit)=1458.173990726471),
#  Row(Customer ID='MY-17380', Customer Name='Maribeth Yedwab', sum(Profit)=1449.8070001602173),
#  Row(Customer ID='EG-13900', Customer Name='Emily Grady', sum(Profit)=1447.7130599021912),
#  Row(Customer ID='MF-18250', Customer Name='Monica Federle', sum(Profit)=1444.280997030437),
#  Row(Customer ID='NP-18670', Customer Name='Nora Paige', sum(Profit)=1444.0140204429626),
#  Row(Customer ID='MR-17545', Customer Name='Mathew Reese', sum(Profit)=1440.0254930257797),
#  Row(Customer ID='CS-11860', Customer Name='Cari Schnelling', sum(Profit)=1439.7254796028137),
#  Row(Customer ID='AW-10930', Customer Name='Arthur Wiediger', sum(Profit)=1424.4539861679077),
#  Row(Customer ID='CS-12460', Customer Name='Chuck Sachs', sum(Profit)=1414.9349958896637),
#  Row(Customer ID='DB-13660', Customer Name='Duane Benoit', sum(Profit)=1401.9839742183685),
#  Row(Customer ID='BS-11365', Customer Name='Bill Shonely', sum(Profit)=1397.325034379959),
#  Row(Customer ID='JC-15385', Customer Name='Jenna Caffey', sum(Profit)=1390.2899932861328),
#  Row(Customer ID='GZ-14470', Customer Name='Gary Zandusky', sum(Profit)=1355.5395226478577),
#  Row(Customer ID='CC-12145', Customer Name='Charles Crestani', sum(Profit)=1353.5579833984375),
#  Row(Customer ID='ES-14020', Customer Name='Erica Smith', sum(Profit)=1337.3205142617226),
#  Row(Customer ID='EH-14125', Customer Name='Eugene Hildebrand', sum(Profit)=1334.6924999952316),
#  Row(Customer ID='AB-10165', Customer Name='Alan Barnes', sum(Profit)=1322.7930009365082),
#  Row(Customer ID='GG-14650', Customer Name='Greg Guthrie', sum(Profit)=1318.7039844989777),
#  Row(Customer ID='TA-21385', Customer Name='Tom Ashbrook', sum(Profit)=1318.4429967403412),
#  Row(Customer ID='DB-12910', Customer Name='Daniel Byrd', sum(Profit)=1314.8759758472443),
#  Row(Customer ID='MY-18295', Customer Name='Muhammed Yedwab', sum(Profit)=1314.7830208539963),
#  Row(Customer ID='EB-13975', Customer Name='Erica Bern', sum(Profit)=1314.5459933280945),
#  Row(Customer ID='RB-19570', Customer Name='Rob Beeghly', sum(Profit)=1300.7759554237127),
#  Row(Customer ID='BP-11290', Customer Name='Beth Paige', sum(Profit)=1296.4379472732544),
#  Row(Customer ID='MT-18070', Customer Name='Michelle Tran', sum(Profit)=1291.8735251426697),
#  Row(Customer ID='CD-12790', Customer Name='Cynthia Delaney', sum(Profit)=1290.3644938468933),
#  Row(Customer ID='CM-12115', Customer Name='Chad McGuire', sum(Profit)=1287.8400163650513),
#  Row(Customer ID='AG-10300', Customer Name='Aleksandra Gannaway', sum(Profit)=1280.598018169403),
#  Row(Customer ID='SR-20740', Customer Name='Steven Roelle', sum(Profit)=1279.199984550476),
#  Row(Customer ID='QJ-19255', Customer Name='Quincy Jones', sum(Profit)=1275.089951992035),
#  Row(Customer ID='CD-11920', Customer Name='Carlos Daly', sum(Profit)=1273.3140043132007),
#  Row(Customer ID='HJ-14875', Customer Name='Heather Jas', sum(Profit)=1264.6575000919402),
#  Row(Customer ID='PS-19045', Customer Name='Penelope Sewall', sum(Profit)=1261.9214668273926),
#  Row(Customer ID='JM-15865', Customer Name='John Murray', sum(Profit)=1259.428477048874),
#  Row(Customer ID='JH-16180', Customer Name='Justin Hirsh', sum(Profit)=1258.769994020462),
#  Row(Customer ID='SH-20635', Customer Name='Stefanie Holloman', sum(Profit)=1254.8024876117706),
#  Row(Customer ID='DJ-13420', Customer Name='Denny Joy', sum(Profit)=1245.5220129489899),
#  Row(Customer ID='LR-17035', Customer Name='Lisa Ryan', sum(Profit)=1231.880977511406),
#  Row(Customer ID='RD-19480', Customer Name='Rick Duston', sum(Profit)=1223.1225204467773),
#  Row(Customer ID='LE-16810', Customer Name='Laurel Elliston', sum(Profit)=1216.1100034713745),
#  Row(Customer ID='MP-17470', Customer Name='Mark Packer', sum(Profit)=1209.0179934203625),
#  Row(Customer ID='TW-21025', Customer Name='Tamara Willingham', sum(Profit)=1203.1350176930428),
#  Row(Customer ID='PW-19030', Customer Name='Pauline Webber', sum(Profit)=1200.8040075302124),
#  Row(Customer ID='MS-17530', Customer Name='MaryBeth Skach', sum(Profit)=1200.627005815506),
#  Row(Customer ID='LD-16855', Customer Name='Lela Donovan', sum(Profit)=1194.2489882707596),
#  Row(Customer ID='SV-20785', Customer Name='Stewart Visinsky', sum(Profit)=1189.7039897441864),
#  Row(Customer ID='RD-19585', Customer Name='Rob Dowd', sum(Profit)=1185.8519966602325),
#  Row(Customer ID='SW-20245', Customer Name='Scot Wooten', sum(Profit)=1183.480504989624),
#  Row(Customer ID='BD-11560', Customer Name='Brendan Dodson', sum(Profit)=1175.220006763935),
#  Row(Customer ID='JF-15295', Customer Name='Jason Fortune-', sum(Profit)=1174.500009059906),
#  Row(Customer ID='AR-10510', Customer Name='Andrew Roberts', sum(Profit)=1173.9899978637695),
#  Row(Customer ID='LO-17170', Customer Name='Lori Olson', sum(Profit)=1171.3649773597717),
#  Row(Customer ID='CH-12070', Customer Name='Cathy Hwang', sum(Profit)=1169.6040034294128),
#  Row(Customer ID='JL-15235', Customer Name='Janet Lee', sum(Profit)=1160.8890144824982),
#  Row(Customer ID='GK-14620', Customer Name='Grace Kelly', sum(Profit)=1147.646976351738),
#  Row(Customer ID='LR-16915', Customer Name='Lena Radford', sum(Profit)=1143.3690032958984),
#  Row(Customer ID='MM-18280', Customer Name='Muhammed MacIntyre', sum(Profit)=1142.7479829788208),
#  Row(Customer ID='JG-15805', Customer Name='John Grady', sum(Profit)=1132.3500004410744),
#  Row(Customer ID='RD-19720', Customer Name='Roger Demir', sum(Profit)=1130.4300098642707),
#  Row(Customer ID='AB-10015', Customer Name='Aaron Bergman', sum(Profit)=1122.8939997851849),
#  Row(Customer ID='RW-19540', Customer Name='Rick Wilson', sum(Profit)=1120.4535112380981),
#  Row(Customer ID='GT-14710', Customer Name='Greg Tran', sum(Profit)=1111.0079997181892),
#  Row(Customer ID='KW-16435', Customer Name='Katrina Willman', sum(Profit)=1101.7200021743774),
#  Row(Customer ID='JK-15640', Customer Name='Jim Kriz', sum(Profit)=1088.655005455017),
#  Row(Customer ID='RS-19765', Customer Name='Roland Schwarz', sum(Profit)=1077.1019949913025),
#  Row(Customer ID='RF-19345', Customer Name='Randy Ferguson', sum(Profit)=1069.5899913311005),
#  Row(Customer ID='ML-17755', Customer Name='Max Ludwig', sum(Profit)=1062.8084678649902),
#  Row(Customer ID='CC-12370', Customer Name='Christopher Conant', sum(Profit)=1061.9400217533112),
#  Row(Customer ID='PB-19210', Customer Name='Phillip Breyer', sum(Profit)=1060.640992641449),
#  Row(Customer ID='LA-16780', Customer Name='Laura Armstrong', sum(Profit)=1053.801017522812),
#  Row(Customer ID='AY-10555', Customer Name='Andy Yotov', sum(Profit)=1041.7680163383484),
#  Row(Customer ID='AB-10060', Customer Name='Adam Bellavance', sum(Profit)=1020.065993309021),
#  Row(Customer ID='AB-10150', Customer Name='Aimee Bixby', sum(Profit)=1009.5119925141335),
#  Row(Customer ID='KD-16270', Customer Name='Karen Daniels', sum(Profit)=1003.9005041718483),
#  Row(Customer ID='JB-15925', Customer Name='Joni Blumstein', sum(Profit)=1003.5869834423065),
#  Row(Customer ID='NZ-18565', Customer Name='Nick Zandusky', sum(Profit)=1002.7439829111099),
#  Row(Customer ID='JF-15415', Customer Name='Jennifer Ferguson', sum(Profit)=995.7779477275908),
#  Row(Customer ID='DK-13150', Customer Name='David Kendrick', sum(Profit)=983.4090216010809),
#  Row(Customer ID='AH-10030', Customer Name='Aaron Hawkins', sum(Profit)=981.5939562320709),
#  Row(Customer ID='DW-13480', Customer Name='Dianna Wilson', sum(Profit)=979.2660224437714),
#  Row(Customer ID='BD-11770', Customer Name='Bryan Davis', sum(Profit)=977.709005355835),
#  Row(Customer ID='JK-15730', Customer Name='Joe Kamberova', sum(Profit)=970.7760094702244),
#  Row(Customer ID='EB-13930', Customer Name='Eric Barreto', sum(Profit)=970.298999786377),
#  Row(Customer ID='DB-13615', Customer Name='Doug Bickford', sum(Profit)=968.487006187439),
#  Row(Customer ID='RB-19360', Customer Name='Raymond Buch', sum(Profit)=967.7339780330658),
#  Row(Customer ID='BF-11170', Customer Name='Ben Ferrer', sum(Profit)=965.3610013723373),
#  Row(Customer ID='RR-19525', Customer Name='Rick Reed', sum(Profit)=965.0339994430542),
#  Row(Customer ID='FH-14350', Customer Name='Fred Harton', sum(Profit)=964.6395227909088),
#  Row(Customer ID='MF-17665', Customer Name='Maureen Fritzler', sum(Profit)=955.3470054268837),
#  Row(Customer ID='MS-17980', Customer Name='Michael Stewart', sum(Profit)=953.5349905490875),
#  Row(Customer ID='RD-19660', Customer Name='Robert Dilbeck', sum(Profit)=949.1969923973083),
#  Row(Customer ID='HE-14800', Customer Name='Harold Engle', sum(Profit)=948.4799818992615),
#  Row(Customer ID='AJ-10945', Customer Name='Ashley Jarboe', sum(Profit)=945.8309783935547),
#  Row(Customer ID='GH-14410', Customer Name='Gary Hansen', sum(Profit)=934.5284640789032),
#  Row(Customer ID='SJ-20215', Customer Name='Sarah Jordon', sum(Profit)=934.4730043411255),
#  Row(Customer ID='JO-15145', Customer Name="Jack O'Briant", sum(Profit)=928.9080111980438),
#  Row(Customer ID='SL-20155', Customer Name='Sara Luxemburg', sum(Profit)=928.0560228824615),
#  Row(Customer ID='JM-15250', Customer Name='Janet Martin', sum(Profit)=925.5179877281189),
#  Row(Customer ID='YS-21880', Customer Name='Yana Sorensen', sum(Profit)=925.3799839019775),
#  Row(Customer ID='ME-17320', Customer Name='Maria Etezadi', sum(Profit)=921.8459402322769),
#  Row(Customer ID='AF-10885', Customer Name='Art Foster', sum(Profit)=921.4800059199333),
#  Row(Customer ID='SC-20725', Customer Name='Steven Cartwright', sum(Profit)=921.3720037937164),
#  Row(Customer ID='ML-18040', Customer Name='Michelle Lonsdale', sum(Profit)=919.7489827275276),
#  Row(Customer ID='AJ-10960', Customer Name='Astrea Jones', sum(Profit)=914.0744862556458),
#  Row(Customer ID='DF-13135', Customer Name='David Flashing', sum(Profit)=912.3180162534118),
#  Row(Customer ID='TG-21310', Customer Name='Toby Gnade', sum(Profit)=909.4200024679303),
#  Row(Customer ID='LH-17155', Customer Name='Logan Haushalter', sum(Profit)=907.1910173594952),
#  Row(Customer ID='MC-17605', Customer Name='Matt Connell', sum(Profit)=906.5100162029266),
#  Row(Customer ID='AH-10120', Customer Name='Adrian Hane', sum(Profit)=905.5109931230545),
#  Row(Customer ID='PR-18880', Customer Name='Patrick Ryan', sum(Profit)=899.5979943275452),
#  Row(Customer ID='DB-13060', Customer Name='Dave Brooks', sum(Profit)=894.902996301651),
#  Row(Customer ID='GH-14665', Customer Name='Greg Hansen', sum(Profit)=892.0920113921165),
#  Row(Customer ID='SP-20860', Customer Name='Sung Pak', sum(Profit)=891.5985670089722),
#  Row(Customer ID='CC-12610', Customer Name='Corey Catlett', sum(Profit)=878.4780026227236),
#  Row(Customer ID='CC-12100', Customer Name='Chad Cunningham', sum(Profit)=873.0269978046417),
#  Row(Customer ID='HM-14980', Customer Name='Henry MacAllister', sum(Profit)=871.746006757021),
#  Row(Customer ID='JC-15775', Customer Name='John Castell', sum(Profit)=866.4689879119396),
#  Row(Customer ID='TS-21370', Customer Name='Todd Sumrall', sum(Profit)=859.6650104522705),
#  Row(Customer ID='EM-14200', Customer Name='Evan Minnotte', sum(Profit)=858.0299911499023),
#  Row(Customer ID='DJ-13510', Customer Name='Don Jones', sum(Profit)=854.4000046253204),
#  Row(Customer ID='DL-13495', Customer Name='Dionis Lloyd', sum(Profit)=851.6429815292358),
#  Row(Customer ID='BG-11740', Customer Name='Bruce Geld', sum(Profit)=849.38249117136),
#  Row(Customer ID='SA-20830', Customer Name='Sue Ann Reed', sum(Profit)=846.3060047626495),
#  Row(Customer ID='RS-19870', Customer Name='Roy Skaria', sum(Profit)=835.453496336937),
#  Row(Customer ID='EH-13945', Customer Name='Eric Hoffmann', sum(Profit)=831.5579690933228),
#  Row(Customer ID='LC-16960', Customer Name='Lindsay Castell', sum(Profit)=830.0939965248108),
#  Row(Customer ID='HH-15010', Customer Name='Hilary Holden', sum(Profit)=829.9694919586182),
#  Row(Customer ID='HA-14905', Customer Name='Helen Abelman', sum(Profit)=824.6100105047226),
#  Row(Customer ID='HZ-14950', Customer Name='Henia Zydlo', sum(Profit)=821.8334829807281),
#  Row(Customer ID='CA-12055', Customer Name='Cathy Armstrong', sum(Profit)=815.619002521038),
#  Row(Customer ID='BP-11230', Customer Name='Benjamin Patterson', sum(Profit)=815.2409834861755),
#  Row(Customer ID='ND-18460', Customer Name='Neil Ducich', sum(Profit)=811.5000002384186),
#  Row(Customer ID='CR-12580', Customer Name='Clay Rozendal', sum(Profit)=809.160017490387),
#  Row(Customer ID='SR-20425', Customer Name='Sharelle Roach', sum(Profit)=806.2004818916321),
#  Row(Customer ID='JM-15580', Customer Name='Jill Matthias', sum(Profit)=801.9030110836029),
#  Row(Customer ID='FH-14365', Customer Name='Fred Hopkins', sum(Profit)=794.1765081882477),
#  Row(Customer ID='DR-12940', Customer Name='Daniel Raglin', sum(Profit)=793.1895179748535),
#  Row(Customer ID='SS-20590', Customer Name='Sonia Sunley', sum(Profit)=791.8169875144958),
#  Row(Customer ID='IG-15085', Customer Name='Ivan Gibson', sum(Profit)=790.664992928505),
#  Row(Customer ID='AH-10690', Customer Name='Anna Häberlin', sum(Profit)=790.008004963398),
#  Row(Customer ID='KL-16645', Customer Name='Ken Lonsdale', sum(Profit)=789.2189980149269),
#  Row(Customer ID='CV-12805', Customer Name='Cynthia Voltz', sum(Profit)=787.6709909439087),
#  Row(Customer ID='AO-10810', Customer Name="Anthony O'Donnell", sum(Profit)=786.6059999465942),
#  Row(Customer ID='TB-21175', Customer Name='Thomas Boland', sum(Profit)=783.5369917154312),
#  Row(Customer ID='DJ-13630', Customer Name='Doug Jacobs', sum(Profit)=781.7369985580444),
#  Row(Customer ID='NG-18430', Customer Name='Nathan Gelder', sum(Profit)=779.048975944519),
#  Row(Customer ID='AR-10345', Customer Name='Alex Russell', sum(Profit)=771.6240081787109),
#  Row(Customer ID='PS-18970', Customer Name='Paul Stevenson', sum(Profit)=769.8315054625273),
#  Row(Customer ID='RA-19885', Customer Name='Ruben Ausman', sum(Profit)=763.4010088443756),
#  Row(Customer ID='JP-15460', Customer Name='Jennifer Patt', sum(Profit)=760.3290071487427),
#  Row(Customer ID='SB-20290', Customer Name='Sean Braxton', sum(Profit)=759.2339954376221),
#  Row(Customer ID='MB-17305', Customer Name='Maria Bertelson', sum(Profit)=756.9030239582062),
#  Row(Customer ID='SO-20335', Customer Name="Sean O'Donnell", sum(Profit)=755.3100066184998),
#  Row(Customer ID='ND-18370', Customer Name='Natalie DeCherney', sum(Profit)=755.2394925057888),
#  Row(Customer ID='MH-17785', Customer Name='Maya Herman', sum(Profit)=750.5640122890472),
#  Row(Customer ID='TP-21130', Customer Name='Theone Pippenger', sum(Profit)=749.1330049037933),
#  Row(Customer ID='BG-11035', Customer Name='Barry Gonzalez', sum(Profit)=747.3599987030029),
#  Row(Customer ID='GH-14485', Customer Name='Gene Hale', sum(Profit)=741.3779965639114),
#  Row(Customer ID='TT-21460', Customer Name='Tonja Turnell', sum(Profit)=740.7690221071243),
#  Row(Customer ID='AT-10735', Customer Name='Annie Thurman', sum(Profit)=736.3829890489578),
#  Row(Customer ID='JE-15715', Customer Name='Joe Elijah', sum(Profit)=734.3970020413399),
#  Row(Customer ID='ML-18265', Customer Name='Muhammed Lee', sum(Profit)=731.1810014247894),
#  Row(Customer ID='KD-16615', Customer Name='Ken Dana', sum(Profit)=730.5254654884338),
#  Row(Customer ID='JL-15130', Customer Name='Jack Lebron', sum(Profit)=727.412971496582),
#  Row(Customer ID='LC-16930', Customer Name='Linda Cazamias', sum(Profit)=722.9669968485832),
#  Row(Customer ID='DB-13210', Customer Name='Dean Braden', sum(Profit)=720.5970004871488),
#  Row(Customer ID='PJ-19015', Customer Name='Pauline Johnson', sum(Profit)=717.9390053749084),
#  Row(Customer ID='JF-15190', Customer Name='Jamie Frazer', sum(Profit)=715.4070100784302),
#  Row(Customer ID='GZ-14545', Customer Name='George Zrebassa', sum(Profit)=708.7650141716003),
#  Row(Customer ID='HW-14935', Customer Name='Helen Wasserman', sum(Profit)=708.5250022411346),
#  Row(Customer ID='HK-14890', Customer Name='Heather Kirkland', sum(Profit)=704.8304982185364),
#  Row(Customer ID='BM-11785', Customer Name='Bryan Mills', sum(Profit)=703.4099950194359),
#  Row(Customer ID='SN-20710', Customer Name='Steve Nguyen', sum(Profit)=701.874014377594),
#  Row(Customer ID='TB-21250', Customer Name='Tim Brockman', sum(Profit)=698.0099952667952),
#  Row(Customer ID='EB-13705', Customer Name='Ed Braxton', sum(Profit)=687.0000095367432),
#  Row(Customer ID='CS-12250', Customer Name='Chris Selesnick', sum(Profit)=684.0135061740875),
#  Row(Customer ID='CC-12220', Customer Name='Chris Cortes', sum(Profit)=683.1240090318024),
#  Row(Customer ID='KM-16660', Customer Name='Khloe Miller', sum(Profit)=681.7829957008362),
#  Row(Customer ID='MC-18130', Customer Name='Mike Caudle', sum(Profit)=681.3479907512665),
#  Row(Customer ID='CG-12520', Customer Name='Claire Gute', sum(Profit)=673.0049889087677),
#  Row(Customer ID='HR-14770', Customer Name='Hallie Redmond', sum(Profit)=667.7819944620132),
#  Row(Customer ID='MG-17650', Customer Name='Matthew Grinstein', sum(Profit)=666.3270002305508),
#  Row(Customer ID='LC-17050', Customer Name='Liz Carlisle', sum(Profit)=665.8379988670349),
#  Row(Customer ID='SC-20695', Customer Name='Steve Chapman', sum(Profit)=662.5424766540527),
#  Row(Customer ID='NM-18520', Customer Name='Neoma Murray', sum(Profit)=662.3759949207306),
#  Row(Customer ID='AG-10330', Customer Name='Alex Grayson', sum(Profit)=661.540502011776),
#  Row(Customer ID='TM-21010', Customer Name='Tamara Manning', sum(Profit)=660.9960134029388),
#  Row(Customer ID='DD-13570', Customer Name='Dorothy Dickinson', sum(Profit)=660.8850047588348),
#  Row(Customer ID='CA-11965', Customer Name='Carol Adams', sum(Profit)=651.8279976844788),
#  Row(Customer ID='SM-20905', Customer Name='Susan MacKendrick', sum(Profit)=646.4550089836121),
#  Row(Customer ID='MC-18100', Customer Name='Mick Crebagga', sum(Profit)=641.0189952850342),
#  Row(Customer ID='BM-11650', Customer Name='Brian Moss', sum(Profit)=637.8870077133179),
#  Row(Customer ID='PS-18760', Customer Name='Pamela Stobb', sum(Profit)=636.2939884662628),
#  Row(Customer ID='JA-15970', Customer Name='Joseph Airdo', sum(Profit)=636.2820100784302),
#  Row(Customer ID='LC-17140', Customer Name='Logan Currie', sum(Profit)=633.2820074558258),
#  Row(Customer ID='CC-12685', Customer Name='Craig Carroll', sum(Profit)=631.5449911355972),
#  Row(Customer ID='BN-11515', Customer Name='Bradley Nguyen', sum(Profit)=631.0514979362488),
#  Row(Customer ID='EL-13735', Customer Name='Ed Ludwig', sum(Profit)=625.6080050468445),
#  Row(Customer ID='MH-18115', Customer Name='Mick Hernandez', sum(Profit)=623.7780017852783),
#  Row(Customer ID='JW-15220', Customer Name='Jane Waco', sum(Profit)=622.3949995040894),
#  Row(Customer ID='SM-20320', Customer Name='Sean Miller', sum(Profit)=620.0430016517639),
#  Row(Customer ID='CB-12535', Customer Name='Claudia Bergmann', sum(Profit)=618.574495613575),
#  Row(Customer ID='FW-14395', Customer Name='Fred Wasserman', sum(Profit)=616.9949905872345),
#  Row(Customer ID='AC-10450', Customer Name='Amy Cox', sum(Profit)=614.1900124549866),
#  Row(Customer ID='TG-21640', Customer Name='Trudy Glocke', sum(Profit)=608.1000043451786),
#  Row(Customer ID='RA-19945', Customer Name='Ryan Akin', sum(Profit)=608.0429863929749),
#  Row(Customer ID='EM-13825', Customer Name='Elizabeth Moffitt', sum(Profit)=607.1549932956696),
#  Row(Customer ID='JP-16135', Customer Name='Julie Prescott', sum(Profit)=606.9329993724823),
#  Row(Customer ID='CL-11890', Customer Name='Carl Ludwig', sum(Profit)=604.3709812164307),
#  Row(Customer ID='CD-12280', Customer Name='Christina DeMoss', sum(Profit)=601.8269860744476),
#  Row(Customer ID='FM-14215', Customer Name='Filia McAdams', sum(Profit)=596.9070020318031),
#  Row(Customer ID='MC-17575', Customer
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# (Customer ID='NP-18325', Customer Name='Naresj Patel', sum(Profit)=189.69900241680443),
#  Row(Customer ID='DP-13105', Customer Name='Dave Poirier', sum(Profit)=188.38800430297852),
#  Row(Customer ID='DO-13645', Customer Name="Doug O'Connell", sum(Profit)=186.33899974822998),
#  Row(Customer ID='FC-14335', Customer Name='Fred Chung', sum(Profit)=186.29250144958496),
#  Row(Customer ID='EJ-14155', Customer Name='Eva Jacobs', sum(Profit)=184.50901299715042),
#  Row(Customer ID='CM-12715', Customer Name='Craig Molinari', sum(Profit)=179.67750120162964),
#  Row(Customer ID='JD-16150', Customer Name='Justin Deggeller', sum(Profit)=179.0909984111786),
#  Row(Customer ID='MP-18175', Customer Name='Mike Pelletier', sum(Profit)=178.72349643707275),
#  Row(Customer ID='NW-18400', Customer Name='Natalie Webber', sum(Profit)=178.01399862766266),
#  Row(Customer ID='KC-16540', Customer Name='Kelly Collister', sum(Profit)=177.57600319385529),
#  Row(Customer ID='TB-21355', Customer Name='Todd Boyes', sum(Profit)=176.4000062942505),
#  Row(Customer ID='TS-21340', Customer Name='Toby Swindell', sum(Profit)=174.6749985218048),
#  Row(Customer ID='GP-14740', Customer Name='Guy Phonely', sum(Profit)=172.08900278806686),
#  Row(Customer ID='EP-13915', Customer Name='Emily Phan', sum(Profit)=171.18900176882744),
#  Row(Customer ID='PH-18790', Customer Name='Patricia Hirasaki', sum(Profit)=169.08300018310547),
#  Row(Customer ID='LS-17245', Customer Name='Lynn Smith', sum(Profit)=164.74200439453125),
#  Row(Customer ID='LP-17095', Customer Name='Liz Preis', sum(Profit)=164.1659984588623),
#  Row(Customer ID='JE-15475', Customer Name='Jeremy Ellison', sum(Profit)=161.9760022163391),
#  Row(Customer ID='ES-14080', Customer Name='Erin Smith', sum(Profit)=161.22299873828888),
#  Row(Customer ID='KM-16720', Customer Name='Kunst Miller', sum(Profit)=160.13999265432358),
#  Row(Customer ID='PB-19150', Customer Name='Philip Brown', sum(Profit)=159.8550009727478),
#  Row(Customer ID='NS-18640', Customer Name='Noel Staavos', sum(Profit)=156.65103739872575),
#  Row(Customer ID='TP-21415', Customer Name='Tom Prescott', sum(Profit)=155.64000034332275),
#  Row(Customer ID='SF-20965', Customer Name='Sylvia Foulston', sum(Profit)=155.3340002298355),
#  Row(Customer ID='AG-10525', Customer Name='Andy Gerbode', sum(Profit)=151.7190136909485),
#  Row(Customer ID='ME-17725', Customer Name='Max Engle', sum(Profit)=151.51500606536865),
#  Row(Customer ID='RW-19690', Customer Name='Robert Waldorf', sum(Profit)=151.09200382232666),
#  Row(Customer ID='CS-12355', Customer Name='Christine Sundaresam', sum(Profit)=148.16400003433228),
#  Row(Customer ID='VW-21775', Customer Name='Victoria Wilson', sum(Profit)=148.0560038778931),
#  Row(Customer ID='SS-20875', Customer Name='Sung Shariari', sum(Profit)=145.78500032424927),
#  Row(Customer ID='EM-13810', Customer Name='Eleni McCrary', sum(Profit)=145.58099365234375),
#  Row(Customer ID='DW-13195', Customer Name='David Wiener', sum(Profit)=144.85799598693848),
#  Row(Customer ID='CM-12235', Customer Name='Chris McAfee', sum(Profit)=144.8280035816133),
#  Row(Customer ID='SC-20230', Customer Name='Scot Coram', sum(Profit)=137.39101123809814),
#  Row(Customer ID='CM-12160', Customer Name='Charles McCrossin', sum(Profit)=136.5690020918846),
#  Row(Customer ID='BW-11065', Customer Name='Barry Weirich', sum(Profit)=136.56599539518356),
#  Row(Customer ID='NF-18595', Customer Name='Nicole Fjeld', sum(Profit)=136.29299258068204),
#  Row(Customer ID='EB-13870', Customer Name='Emily Burns', sum(Profit)=136.28400325775146),
#  Row(Customer ID='RL-19615', Customer Name='Rob Lucas', sum(Profit)=134.81999826431274),
#  Row(Customer ID='PB-18805', Customer Name='Patrick Bzostek', sum(Profit)=134.32649564743042),
#  Row(Customer ID='DB-12970', Customer Name='Darren Budd', sum(Profit)=133.9589967727661),
#  Row(Customer ID='NK-18490', Customer Name='Neil Knudson', sum(Profit)=132.50399923324585),
#  Row(Customer ID='BD-11725', Customer Name='Bruce Degenhardt', sum(Profit)=132.26849973201752),
#  Row(Customer ID='GD-14590', Customer Name='Giulietta Dortch', sum(Profit)=132.02849501371384),
#  Row(Customer ID='CS-12505', Customer Name='Cindy Stewart', sum(Profit)=131.0490002632141),
#  Row(Customer ID='SC-20440', Customer Name='Shaun Chance', sum(Profit)=130.17600274085999),
#  Row(Customer ID='NC-18535', Customer Name='Nick Crebassa', sum(Profit)=128.3819995764643),
#  Row(Customer ID='AZ-10750', Customer Name='Annie Zypern', sum(Profit)=128.3129997253418),
#  Row(Customer ID='PK-18910', Customer Name='Paul Knutson', sum(Profit)=127.7759975194931),
#  Row(Customer ID='ST-20530', Customer Name='Shui Tom', sum(Profit)=126.71400308609009),
#  Row(Customer ID='PK-19075', Customer Name='Pete Kriz', sum(Profit)=126.59099504351616),
#  Row(Customer ID='GA-14725', Customer Name='Guy Armstrong', sum(Profit)=125.90399807691574),
#  Row(Customer ID='TH-21115', Customer Name='Thea Hudgings', sum(Profit)=125.57999753952026),
#  Row(Customer ID='EN-13780', Customer Name='Edward Nazzal', sum(Profit)=125.4779963195324),
#  Row(Customer ID='JL-15175', Customer Name='James Lanier', sum(Profit)=125.4719967842102),
#  Row(Customer ID='JM-15535', Customer Name='Jessica Myrick', sum(Profit)=122.9999988079071),
#  Row(Customer ID='MG-17890', Customer Name='Michael Granlund', sum(Profit)=122.4149931371212),
#  Row(Customer ID='RH-19600', Customer Name='Rob Haberlin', sum(Profit)=122.20799970626831),
#  Row(Customer ID='SF-20065', Customer Name='Sandra Flanagan', sum(Profit)=121.46998453140259),
#  Row(Customer ID='MC-17845', Customer Name='Michael Chen', sum(Profit)=120.58799688518047),
#  Row(Customer ID='LW-17125', Customer Name='Liz Willingham', sum(Profit)=120.56100583076477),
#  Row(Customer ID='AD-10180', Customer Name='Alan Dominguez', sum(Profit)=119.87850284576416),
#  Row(Customer ID='MC-17425', Customer Name='Mark Cousins', sum(Profit)=119.47200274467468),
#  Row(Customer ID='MO-17950', Customer Name='Michael Oakman', sum(Profit)=117.7259932756424),
#  Row(Customer ID='ME-18010', Customer Name='Michelle Ellison', sum(Profit)=116.18400585651398),
#  Row(Customer ID='JW-15955', Customer Name='Joni Wasserman', sum(Profit)=114.09298665821552),
#  Row(Customer ID='JK-15325', Customer Name='Jason Klamczynski', sum(Profit)=113.26499891281128),
#  Row(Customer ID='DV-13465', Customer Name='Dianna Vittorini', sum(Profit)=112.9500025510788),
#  Row(Customer ID='AG-10765', Customer Name='Anthony Garverick', sum(Profit)=110.80200052261353),
#  Row(Customer ID='TC-21535', Customer Name='Tracy Collins', sum(Profit)=110.13000512123108),
#  Row(Customer ID='DB-13360', Customer Name='Dennis Bolton', sum(Profit)=109.42798900604248),
#  Row(Customer ID='SV-20815', Customer Name='Stuart Van', sum(Profit)=109.20749910920858),
#  Row(Customer ID='DB-13405', Customer Name='Denny Blanton', sum(Profit)=107.70149731636047),
#  Row(Customer ID='KN-16705', Customer Name='Kristina Nunn', sum(Profit)=107.17800116539001),
#  Row(Customer ID='RW-19630', Customer Name='Rob Williams', sum(Profit)=106.52550240792334),
#  Row(Customer ID='JD-16015', Customer Name='Joy Daniels', sum(Profit)=105.66000008583069),
#  Row(Customer ID='SW-20755', Customer Name='Steven Ward', sum(Profit)=105.20399445667863),
#  Row(Customer ID='EB-14170', Customer Name='Evan Bailliet', sum(Profit)=104.28000259399414),
#  Row(Customer ID='JO-15280', Customer Name="Jas O'Carroll", sum(Profit)=103.19999694824219),
#  Row(Customer ID='MO-17800', Customer Name="Meg O'Connel", sum(Profit)=100.58999681472778),
#  Row(Customer ID='EH-13990', Customer Name='Erica Hackney', sum(Profit)=98.81100273132324),
#  Row(Customer ID='TB-21280', Customer Name='Toby Braunhardt', sum(Profit)=98.55899977684021),
#  Row(Customer ID='VM-21835', Customer Name='Vivian Mathis', sum(Profit)=97.77900266647339),
#  Row(Customer ID='MD-17350', Customer Name='Maribeth Dona', sum(Profit)=95.7870010137558),
#  Row(Customer ID='MC-17275', Customer Name='Marc Crier', sum(Profit)=95.60549759864807),
#  Row(Customer ID='CJ-11875', Customer Name='Carl Jackson', sum(Profit)=94.42200267314911),
#  Row(Customer ID='SP-20650', Customer Name='Stephanie Phelps', sum(Profit)=93.11999988555908),
#  Row(Customer ID='EM-14140', Customer Name='Eugene Moren', sum(Profit)=92.61300015449524),
#  Row(Customer ID='KB-16315', Customer Name='Karl Braun', sum(Profit)=92.14500260353088),
#  Row(Customer ID='RA-19915', Customer Name='Russell Applegate', sum(Profit)=91.80898785591125),
#  Row(Customer ID='BM-11575', Customer Name='Brendan Murry', sum(Profit)=90.75600147247314),
#  Row(Customer ID='DK-13375', Customer Name='Dennis Kane', sum(Profit)=90.34501731395721),
#  Row(Customer ID='FM-14290', Customer Name='Frank Merwin', sum(Profit)=90.26699733734131),
#  Row(Customer ID='LP-17080', Customer Name='Liz Pelletier', sum(Profit)=89.46598988771439),
#  Row(Customer ID='NP-18685', Customer Name='Nora Pelletier', sum(Profit)=86.80050092935562),
#  Row(Customer ID='MN-17935', Customer Name='Michael Nguyen', sum(Profit)=86.58899021148682),
#  Row(Customer ID='ED-13885', Customer Name='Emily Ducich', sum(Profit)=83.89200228452682),
#  Row(Customer ID='DG-13300', Customer Name='Deirdre Greer', sum(Profit)=80.87999747693539),
#  Row(Customer ID='DB-13555', Customer Name='Dorothy Badders', sum(Profit)=77.66699683666229),
#  Row(Customer ID='DW-13585', Customer Name='Dorothy Wardle', sum(Profit)=77.28000068664551),
#  Row(Customer ID='DO-13435', Customer Name='Denny Ordway', sum(Profit)=77.11200618743896),
#  Row(Customer ID='MG-17875', Customer Name='Michael Grace', sum(Profit)=77.08948135375977),
#  Row(Customer ID='BT-11440', Customer Name='Bobby Trafton', sum(Profit)=76.90199422836304),
#  Row(Customer ID='JR-15670', Customer Name='Jim Radford', sum(Profit)=74.49300146102905),
#  Row(Customer ID='JH-15430', Customer Name='Jennifer Halladay', sum(Profit)=67.98750221729279),
#  Row(Customer ID='CR-12730', Customer Name='Craig Reiter', sum(Profit)=65.27099990844727),
#  Row(Customer ID='VF-21715', Customer Name='Vicky Freymann', sum(Profit)=64.63199830055237),
#  Row(Customer ID='MH-18025', Customer Name='Michelle Huthwaite', sum(Profit)=64.47450304031372),
#  Row(Customer ID='KH-16630', Customer Name='Ken Heidel', sum(Profit)=63.840001926757395),
#  Row(Customer ID='AH-10465', Customer Name='Amy Hunt', sum(Profit)=59.74799919128418),
#  Row(Customer ID='KM-16225', Customer Name='Kalyca Meade', sum(Profit)=59.3999981880188),
#  Row(Customer ID='BM-11140', Customer Name='Becky Martin', sum(Profit)=56.524497866630554),
#  Row(Customer ID='LH-16900', Customer Name='Lena Hernandez', sum(Profit)=55.49999761581421),
#  Row(Customer ID='LS-16975', Customer Name='Lindsay Shagiari', sum(Profit)=53.73000383377075),
#  Row(Customer ID='EJ-13720', Customer Name='Ed Jacobs', sum(Profit)=52.14000201225281),
#  Row(Customer ID='JL-15505', Customer Name='Jeremy Lonsdale', sum(Profit)=50.624999046325684),
#  Row(Customer ID='TT-21265', Customer Name='Tim Taslimi', sum(Profit)=49.23299813270569),
#  Row(Customer ID='DC-13285', Customer Name='Debra Catini', sum(Profit)=48.7874972820282),
#  Row(Customer ID='LS-16945', Customer Name='Linda Southworth', sum(Profit)=48.34200572967529),
#  Row(Customer ID='CA-12775', Customer Name='Cynthia Arntzen', sum(Profit)=39.51000294089317),
#  Row(Customer ID='RP-19390', Customer Name='Resi Pölking', sum(Profit)=36.55500066280365),
#  Row(Customer ID='EC-14050', Customer Name='Erin Creighton', sum(Profit)=33.420000076293945),
#  Row(Customer ID='DL-12925', Customer Name='Daniel Lacy', sum(Profit)=31.559999465942383),
#  Row(Customer ID='LW-17215', Customer Name='Luke Weiss', sum(Profit)=30.930000245571136),
#  Row(Customer ID='GM-14500', Customer Name='Gene McClure', sum(Profit)=29.610000133514404),
#  Row(Customer ID='SW-20350', Customer Name='Sean Wendt', sum(Profit)=29.406007289886475),
#  Row(Customer ID='AG-10390', Customer Name='Allen Goldenen', sum(Profit)=28.842000007629395),
#  Row(Customer ID='PO-19180', Customer Name='Philisse Overcash', sum(Profit)=27.495004892349243),
#  Row(Customer ID='MO-17500', Customer Name="Mary O'Rourke", sum(Profit)=26.37298846244812),
#  Row(Customer ID='SC-20380', Customer Name='Shahid Collister', sum(Profit)=25.61700189113617),
#  Row(Customer ID='CM-12445', Customer Name='Chuck Magee', sum(Profit)=24.697498321533203),
#  Row(Customer ID='KH-16360', Customer Name='Katherine Hughes', sum(Profit)=19.991994380950928),
#  Row(Customer ID='MK-18160', Customer Name='Mike Kennedy', sum(Profit)=14.76600468158722),
#  Row(Customer ID='SG-20605', Customer Name='Speros Goranitis', sum(Profit)=14.34600019454956),
#  Row(Customer ID='RB-19435', Customer Name='Richard Bierner', sum(Profit)=13.8149995803833),
#  Row(Customer ID='VG-21790', Customer Name='Vivek Gonzalez', sum(Profit)=12.919504642486572),
#  Row(Customer ID='BO-11350', Customer Name='Bill Overfelt', sum(Profit)=8.89799976348877),
#  Row(Customer ID='RD-19900', Customer Name='Ruben Dartt', sum(Profit)=7.230000019073486),
#  Row(Customer ID='JE-15610', Customer Name='Jim Epp', sum(Profit)=6.37799859046936),
#  Row(Customer ID='CC-12430', Customer Name='Chuck Clark', sum(Profit)=6.239999771118164),
#  Row(Customer ID='VG-21805', Customer Name='Vivek Grady', sum(Profit)=3.8999977111816406),
#  Row(Customer ID='AR-10540', Customer Name='Andy Reiter', sum(Profit)=1.4970000386238098),
#  Row(Customer ID='AP-10915', Customer Name='Arthur Prichep', sum(Profit)=-0.955500602722168),
#  Row(Customer ID='KT-16480', Customer Name='Kean Thornton', sum(Profit)=-1.6499992609024048),
#  Row(Customer ID='RB-19705', Customer Name='Roger Barcio', sum(Profit)=-1.8359994888305664),
#  Row(Customer ID='PF-19120', Customer Name='Peter Fuller', sum(Profit)=-6.471000671386719),
#  Row(Customer ID='TB-21400', Customer Name='Tom Boeckenhauer', sum(Profit)=-8.309988975524902),
#  Row(Customer ID='BD-11635', Customer Name='Brian Derr', sum(Profit)=-11.117965459823608),
#  Row(Customer ID='RD-19930', Customer Name="Russell D'Ascenzo", sum(Profit)=-12.58199954032898),
#  Row(Customer ID='JO-15550', Customer Name='Jesus Ocampo', sum(Profit)=-14.153997421264648),
#  Row(Customer ID='TS-21205', Customer Name='Thomas Seio', sum(Profit)=-16.862995862960815),
#  Row(Customer ID='KM-16375', Customer Name='Katherine Murray', sum(Profit)=-16.878009108826518),
#  Row(Customer ID='DS-13030', Customer Name='Darrin Sayre', sum(Profit)=-20.14800465106964),
#  Row(Customer ID='JM-16195', Customer Name='Justin MacKendrick', sum(Profit)=-20.745001792907715),
#  Row(Customer ID='PF-19225', Customer Name='Phillip Flathmann', sum(Profit)=-21.026973485946655),
#  Row(Customer ID='RH-19510', Customer Name='Rick Huthwaite', sum(Profit)=-22.66499614715576),
#  Row(Customer ID='CA-12310', Customer Name='Christine Abelman', sum(Profit)=-32.57099822163582),
#  Row(Customer ID='LH-17020', Customer Name='Lisa Hazard', sum(Profit)=-43.17600345611572),
#  Row(Customer ID='SZ-20035', Customer Name='Sam Zeldin', sum(Profit)=-47.52000045776367),
#  Row(Customer ID='BF-11080', Customer Name='Bart Folk', sum(Profit)=-47.901001930236816),
#  Row(Customer ID='NB-18580', Customer Name='Nicole Brennan', sum(Profit)=-48.0),
#  Row(Customer ID='TB-21190', Customer Name='Thomas Brumley', sum(Profit)=-48.18000149726868),
#  Row(Customer ID='AS-10240', Customer Name='Alan Shonely', sum(Profit)=-49.37698698043823),
#  Row(Customer ID='BD-11500', Customer Name='Bradley Drucker', sum(Profit)=-56.380496084690094),
#  Row(Customer ID='AA-10375', Customer Name='Allen Armold', sum(Profit)=-60.257999420166016),
#  Row(Customer ID='ML-17410', Customer Name='Maris LaWare', sum(Profit)=-67.97099938988686),
#  Row(Customer ID='VB-21745', Customer Name='Victoria Brennan', sum(Profit)=-69.6510100364685),
#  Row(Customer ID='HR-14830', Customer Name='Harold Ryan', sum(Profit)=-76.04999899864197),
#  Row(Customer ID='CS-11845', Customer Name='Cari Sayre', sum(Profit)=-81.89699268341064),
#  Row(Customer ID='PL-18925', Customer Name='Paul Lucas', sum(Profit)=-83.34899806976318),
#  Row(Customer ID='CS-12490', Customer Name='Cindy Schnelling', sum(Profit)=-84.30000752210617),
#  Row(Customer ID='AC-10660', Customer Name='Anna Chung', sum(Profit)=-87.87600612640381),
#  Row(Customer ID='LF-17185', Customer Name='Luke Foster', sum(Profit)=-103.31700241565704),
#  Row(Customer ID='JH-15985', Customer Name='Joseph Holt', sum(Profit)=-106.47900629043579),
#  Row(Customer ID='JS-15880', Customer Name='John Stevenson', sum(Profit)=-109.54800271987915),
#  Row(Customer ID='IL-15100', Customer Name='Ivan Liston', sum(Profit)=-115.62300968170166),
#  Row(Customer ID='MG-17680', Customer Name='Maureen Gastineau', sum(Profit)=-119.32799029350281),
#  Row(Customer ID='SU-20665', Customer Name='Stephanie Ulpright', sum(Profit)=-131.42099714279175),
#  Row(Customer ID='CG-12040', Customer Name='Catherine Glotzbach', sum(Profit)=-139.86000037193298),
#  Row(Customer ID='TB-21055', Customer Name='Ted Butterfield', sum(Profit)=-147.23100650310516),
#  Row(Customer ID='XP-21865', Customer Name='Xylona Preis', sum(Profit)=-152.3520302772522),
#  Row(Customer ID='GA-14515', Customer Name='George Ashbrook', sum(Profit)=-153.33301496505737),
#  Row(Customer ID='TC-21295', Customer Name='Toby Carlisle', sum(Profit)=-155.29352324269712),
#  Row(Customer ID='Co-12640', Customer Name='Corey-Lock', sum(Profit)=-160.01701736450195),
#  Row(Customer ID='TS-21430', Customer Name='Tom Stivers', sum(Profit)=-167.98650336265564),
#  Row(Customer ID='NS-18505', Customer Name='Neola Schneider', sum(Profit)=-169.9139907360077),
#  Row(Customer ID='AF-10870', Customer Name='Art Ferguson', sum(Profit)=-172.30207991600037),
#  Row(Customer ID='MT-17815', Customer Name='Meg Tillman', sum(Profit)=-174.87300366163254),
#  Row(Customer ID='KT-16465', Customer Name='Kean Takahito', sum(Profit)=-179.89500147104263),
#  Row(Customer ID='RM-19375', Customer Name='Raymond Messe', sum(Profit)=-184.1970090866089),
#  Row(Customer ID='LS-17200', Customer Name='Luke Schmidt', sum(Profit)=-197.81250667572021),
#  Row(Customer ID='SP-20545', Customer Name='Sibella Parks', sum(Profit)=-206.50800466537476),
#  Row(Customer ID='SH-19975', Customer Name='Sally Hughsby', sum(Profit)=-212.41501140594482),
#  Row(Customer ID='DM-13345', Customer Name='Denise Monton', sum(Profit)=-213.09298491477966),
#  Row(Customer ID='AR-10405', Customer Name='Allen Rosenblatt', sum(Profit)=-231.95699911378324),
#  Row(Customer ID='JS-16030', Customer Name='Joy Smith', sum(Profit)=-237.23700476251543),
#  Row(Customer ID='RH-19555', Customer Name='Ritsa Hightower', sum(Profit)=-238.6860020160675),
#  Row(Customer ID='CJ-12010', Customer Name='Caroline Jumper', sum(Profit)=-248.25150108337402),
#  Row(Customer ID='DM-13015', Customer Name='Darrin Martin', sum(Profit)=-265.2059944868088),
#  Row(Customer ID='PB-19105', Customer Name='Peter Bühler', sum(Profit)=-283.304998755455),
#  Row(Customer ID='SS-20515', Customer Name='Shirley Schmidt', sum(Profit)=-285.44398379325867),
#  Row(Customer ID='LC-16885', Customer Name='Lena Creighton', sum(Profit)=-290.0160131454468),
#  Row(Customer ID='NP-18700', Customer Name='Nora Preis', sum(Profit)=-303.0420026779175),
#  Row(Customer ID='DP-13165', Customer Name='David Philippe', sum(Profit)=-306.21899485588074),
#  Row(Customer ID='SJ-20500', Customer Name='Shirley Jackson', sum(Profit)=-307.87200903892517),
#  Row(Customer ID='MS-17365', Customer Name='Maribeth Schnelling', sum(Profit)=-313.3260022997856),
#  Row(Customer ID='EH-14005', Customer Name='Erica Hernandez', sum(Profit)=-320.0069785118103),
#  Row(Customer ID='ML-17395', Customer Name='Marina Lichtenstein', sum(Profit)=-322.2779996395111),
#  Row(Customer ID='SM-20005', Customer Name='Sally Matthias', sum(Profit)=-330.7560136318207),
#  Row(Customer ID='SW-20275', Customer Name='Scott Williamson', sum(Profit)=-335.50348603725433),
#  Row(Customer ID='JF-15490', Customer Name='Jeremy Farry', sum(Profit)=-345.1335070133209),
#  Row(Customer ID='BG-11695', Customer Name='Brooke Gillingham', sum(Profit)=-351.33001136779785),
#  Row(Customer ID='FP-14320', Customer Name='Frank Preis', sum(Profit)=-372.0029967427254),
#  Row(Customer ID='SB-20170', Customer Name='Sarah Bern', sum(Profit)=-382.1205038353801),
#  Row(Customer ID='JD-15895', Customer Name='Jonathan Doherty', sum(Profit)=-382.3350158929825),
#  Row(Customer ID='KB-16405', Customer Name='Katrina Bavinger', sum(Profit)=-390.8504713624716),
#  Row(Customer ID='CM-12385', Customer Name='Christopher Martinez', sum(Profit)=-391.94999074935913),
#  Row(Customer ID='AC-10615', Customer Name='Ann Chong', sum(Profit)=-394.9199867248535),
#  Row(Customer ID='AW-10840', Customer Name='Anthony Witt', sum(Profit)=-395.8860094547272),
#  Row(Customer ID='JG-15115', Customer Name='Jack Garza', sum(Profit)=-397.028979241848),
#  Row(Customer ID='DK-12895', Customer Name='Dana Kaydos', sum(Profit)=-400.9769926071167),
#  Row(Customer ID='TN-21040', Customer Name='Tanja Norvell', sum(Profit)=-401.84400248527527),
#  Row(Customer ID='RK-19300', Customer Name='Ralph Kennedy', sum(Profit)=-405.2624925374985),
#  Row(Customer ID='CC-12670', Customer Name='Craig Carreira', sum(Profit)=-414.12300565838814),
#  Row(Customer ID='SC-20305', Customer Name='Sean Christensen', sum(Profit)=-418.01699949707836),
#  Row(Customer ID='GB-14530', Customer Name='George Bell', sum(Profit)=-420.72601222991943),
#  Row(Customer ID='BF-11005', Customer Name='Barry Franz', sum(Profit)=-430.3800011277199),
#  Row(Customer ID='ZC-21910', Customer Name='Zuschuss Carroll', sum(Profit)=-464.51098573207855),
#  Row(Customer ID='LD-17005', Customer Name='Lisa DeCherney', sum(Profit)=-476.7989935874939),
#  Row(Customer ID='EM-13960', Customer Name='Eric Murdock', sum(Profit)=-482.15999805927277),
#  Row(Customer ID='AB-10600', Customer Name='Ann Blume', sum(Profit)=-503.29498863220215),
#  Row(Customer ID='MM-17920', Customer Name='Michael Moore', sum(Profit)=-508.47900772094727),
#  Row(Customer ID='TC-20980', Customer Name='Tamara Chand', sum(Profit)=-509.87102460861206),
#  Row(Customer ID='MA-17560', Customer Name='Matt Abelman', sum(Profit)=-574.9469810724258),
#  Row(Customer ID='BN-11470', Customer Name='Brad Norvell', sum(Profit)=-599.0040144920349),
#  Row(Customer ID='SG-20470', Customer Name='Sheri Gordon', sum(Profit)=-608.5559844970703),
#  Row(Customer ID='EH-13765', Customer Name='Edward Hooks', sum(Profit)=-608.9940118789673),
#  Row(Customer ID='MZ-17515', Customer Name='Mary Zewe', sum(Profit)=-609.574511051178),
#  Row(Customer ID='TD-20995', Customer Name='Tamara Dahlen', sum(Profit)=-628.9799826145172),
#  Row(Customer ID='DB-13120', Customer Name='David Bremer', sum(Profit)=-693.7695016860962),
#  Row(Customer ID='KA-16525', Customer Name='Kelly Andreada', sum(Profit)=-699.2010116577148),
#  Row(Customer ID='HF-14995', Customer Name='Herbert Flentye', sum(Profit)=-722.0910088419914),
#  Row(Customer ID='JD-16060', Customer Name='Julia Dunbar', sum(Profit)=-768.171013392508),
#  Row(Customer ID='BT-11680', Customer Name='Brian Thompson', sum(Profit)=-782.9400064945221),
#  Row(Customer ID='IM-15070', Customer Name='Irene Maddox', sum(Profit)=-795.0390142053366),
#  Row(Customer ID='GM-14440', Customer Name='Gary McGarr', sum(Profit)=-837.746997833252),
#  Row(Customer ID='DL-12865', Customer Name='Dan Lawera', sum(Profit)=-850.782001234591),
#  Row(Customer ID='MG-17695', Customer Name='Maureen Gnade', sum(Profit)=-881.7659585624933),
#  Row(Customer ID='ZD-21925', Customer Name='Zuschuss Donatelli', sum(Profit)=-893.2785239219666),
#  Row(Customer ID='JB-16045', Customer Name='Julia Barnett', sum(Profit)=-912.9240076541901),
#  Row(Customer ID='CS-11950', Customer Name='Carlos Soltero', sum(Profit)=-939.1800059080124),
#  Row(Customer ID='DA-13450', Customer Name='Dianna Arnett', sum(Profit)=-945.2040014266968),
#  Row(Customer ID='KE-16420', Customer Name='Katrina Edelman', sum(Profit)=-945.3719768673182),
#  Row(Customer ID='LL-16840', Customer Name='Lauren Leatherbury', sum(Profit)=-954.8729958534241),
#  Row(Customer ID='JC-15340', Customer Name='Jasper Cacioppo', sum(Profit)=-1046.9370275735855),
#  Row(Customer ID='GM-14695', Customer Name='Greg Maxwell', sum(Profit)=-1107.818991407752),
#  Row(Customer ID='MW-18235', Customer Name='Mitch Willingham', sum(Profit)=-1258.9769654273987),
#  Row(Customer ID='SP-20620', Customer Name='Stefania Perrino', sum(Profit)=-1259.2800500392914),
#  Row(Customer ID='CL-12565', Customer Name='Clay Ludtke', sum(Profit)=-1374.2549903392792),
#  Row(Customer ID='CM-11815', Customer Name='Candace McMahon', sum(Profit)=-1649.8109811358154),
#  Row(Customer ID='DM-13525', Customer Name='Don Miller', sum(Profit)=-1682.9699549674988),
#  Row(Customer ID='HG-14845', Customer Name='Harry Greene', sum(Profit)=-1698.8655061721802),
#  Row(Customer ID='CM-12655', Customer Name='Corinna Mitchell', sum(Profit)=-1765.3635170459747),
#  Row(Customer ID='BF-11215', Customer Name='Benjamin Farhat', sum(Profit)=-1831.0349846482277),
#  Row(Customer ID='NL-18310', Customer Name='Nancy Lomonaco', sum(Profit)=-1898.7059680819511),
#  Row(Customer ID='DP-13000', Customer Name='Darren Powers', sum(Profit)=-1914.5579636693),
#  Row(Customer ID='GM-14680', Customer Name='Greg Matthias', sum(Profit)=-2162.064017176628),
#  Row(Customer ID='VM-21685', Customer Name='Valerie Mitchum', sum(Profit)=-2458.938040494919),
#  Row(Customer ID='SS-20140', Customer Name='Saphhira Shifley', sum(Profit)=-3957.1380457878113)]

# %%
cust_profit.count()
# Out:
# Out[25]: 795

# %%
df = df.withColumn("Orginal Value of Sale",df['Sales']/(1-df['Discount']))
df.show()
# Out:
# +------+---------------+----------+---------+--------------+-----------+----------------+-----------+-------------+--------------------+--------------+-------+---------------+---------------+------------+--------------------+--------+--------+--------+-------+---------------------+
# |Row ID|       Order ID|Order Date|Ship Date|     Ship Mode|Customer ID|   Customer Name|    Segment|         City|               State|       Country| Region|     Product ID|       Category|Sub-Category|        Product Name|   Sales|Quantity|Discount| Profit|Orginal Value of Sale|
# +------+---------------+----------+---------+--------------+-----------+----------------+-----------+-------------+--------------------+--------------+-------+---------------+---------------+------------+--------------------+--------+--------+--------+-------+---------------------+
# |     1|ES-2017-1311038|      null|     null|Standard Class|   AS-10045|  Aaron Smayling|  Corporate|        Leeds|             England|United Kingdom|  North|OFF-ST-10000988|Office Supplies|     Storage|Fellowes Folders,...|    79.2|       3|       0|   39.6|    79.19999694824219|
# |     2|ES-2017-1311038|      null|     null|Standard Class|   AS-10045|  Aaron Smayling|  Corporate|        Leeds|             England|United Kingdom|  North|TEC-AC-10004144|     Technology| Accessories|SanDisk Numeric K...|  388.92|       7|       0|    0.0|    388.9200134277344|
# |     3|ES-2017-1311038|      null|     null|Standard Class|   AS-10045|  Aaron Smayling|  Corporate|        Leeds|             England|United Kingdom|  North|OFF-LA-10001915|Office Supplies|      Labels|Avery Legal Exhib...|   35.19|       3|       0|  16.11|   35.189998626708984|
# |     4|ES-2017-1311038|      null|     null|Standard Class|   AS-10045|  Aaron Smayling|  Corporate|        Leeds|             England|United Kingdom|  North|OFF-ST-10004550|Office Supplies|     Storage|Fellowes Folders,...|   50.94|       2|       0|   13.2|   50.939998626708984|
# |     5|ES-2017-1311038|      null|     null|Standard Class|   AS-10045|  Aaron Smayling|  Corporate|        Leeds|             England|United Kingdom|  North|TEC-AC-10004068|     Technology| Accessories|Memorex Memory Ca...|  307.44|       3|       0|  73.71|   307.44000244140625|
# |     6|ES-2017-1311038|      null|     null|Standard Class|   AS-10045|  Aaron Smayling|  Corporate|        Leeds|             England|United Kingdom|  North|OFF-ST-10002271|Office Supplies|     Storage|Rogers Shelving, ...|   122.4|       2|       0|  37.92|    122.4000015258789|
# |     7|ES-2017-1311038|      null|     null|Standard Class|   AS-10045|  Aaron Smayling|  Corporate|        Leeds|             England|United Kingdom|  North|TEC-PH-10003963|     Technology|      Phones|Apple Signal Boos...|  413.82|       3|       0|  20.61|   413.82000732421875|
# |     8|ES-2015-5113958|      null|     null|  Second Class|   EB-13840|   Ellis Ballard|  Corporate|West Bromwich|             England|United Kingdom|  North|TEC-CO-10004325|     Technology|     Copiers|Canon Personal Co...|  428.22|       3|       0| 192.69|    428.2200012207031|
# |     9|ES-2015-5113958|      null|     null|  Second Class|   EB-13840|   Ellis Ballard|  Corporate|West Bromwich|             England|United Kingdom|  North|OFF-AP-10004512|Office Supplies|  Appliances|   Hoover Stove, Red| 3979.29|       7|       0|1989.54|      3979.2900390625|
# |    10|ES-2015-5113958|      null|     null|  Second Class|   EB-13840|   Ellis Ballard|  Corporate|West Bromwich|             England|United Kingdom|  North|OFF-FA-10002393|Office Supplies|   Fasteners|Accos Push Pins, ...|   43.56|       3|       0|   12.6|   43.560001373291016|
# |    11|ES-2015-2510515|      null|     null|      Same Day|   LH-17155|Logan Haushalter|   Consumer|   Le Bouscat|Aquitaine-Limousi...|        France|Central|OFF-LA-10002805|Office Supplies|      Labels|Hon Color Coded L...|   25.26|       2|       0|   0.48|   25.260000228881836|
# |    12|ES-2015-2510515|      null|     null|      Same Day|   LH-17155|Logan Haushalter|   Consumer|   Le Bouscat|Aquitaine-Limousi...|        France|Central|OFF-AP-10002330|Office Supplies|  Appliances|Hamilton Beach St...|2443.905|       5|    null|760.305|                 null|
# |    13|ES-2015-2510515|      null|     null|      Same Day|   LH-17155|Logan Haushalter|   Consumer|   Le Bouscat|Aquitaine-Limousi...|        France|Central|OFF-AR-10000505|Office Supplies|         Art|Binney & Smith Pe...|   12.21|       1|       0|    0.0|   12.210000038146973|
# |    14|ES-2015-2510515|      null|     null|      Same Day|   LH-17155|Logan Haushalter|   Consumer|   Le Bouscat|Aquitaine-Limousi...|        France|Central|TEC-PH-10002898|     Technology|      Phones|Samsung Smart Pho...|2167.296|       4|    null|790.416|                 null|
# |    15|ES-2015-2510515|      null|     null|      Same Day|   LH-17155|Logan Haushalter|   Consumer|   Le Bouscat|Aquitaine-Limousi...|        France|Central|OFF-ST-10001413|Office Supplies|     Storage|Rogers Folders, Blue| 138.105|       5|    null|-12.345|                 null|
# |    16|ES-2016-4380115|      null|     null|Standard Class|   KC-16540| Kelly Collister|   Consumer|   Strasbourg|Alsace-Champagne-...|        France|Central|OFF-ST-10003931|Office Supplies|     Storage|Smead Trays, Wire...| 128.385|       3|    null|  4.275|                 null|
# |    17|ES-2016-4380115|      null|     null|Standard Class|   KC-16540| Kelly Collister|   Consumer|   Strasbourg|Alsace-Champagne-...|        France|Central|TEC-AC-10004269|     Technology| Accessories|Belkin Memory Car...|  690.12|       6|       0|    0.0|    690.1199951171875|
# |    18|ES-2016-4380115|      null|     null|Standard Class|   KC-16540| Kelly Collister|   Consumer|   Strasbourg|Alsace-Champagne-...|        France|Central|OFF-LA-10001676|Office Supplies|      Labels|Hon Removable Lab...|    8.16|       1|       0|   1.14|     8.15999984741211|
# |    19|ES-2017-2573330|      null|     null|Standard Class|   BF-11170|      Ben Ferrer|Home Office|         Unna|North Rhine-Westp...|       Germany|Central|TEC-MA-10000811|     Technology|    Machines|Okidata Phone, Du...|  347.88|       4|       0|  76.44|    347.8800048828125|
# |    20|ES-2017-2573330|      null|     null|Standard Class|   BF-11170|      Ben Ferrer|Home Office|         Unna|North Rhine-Westp...|       Germany|Central|OFF-ST-10000648|Office Supplies|     Storage|Eldon File Cart, ...| 575.505|       5|    null| 12.705|                 null|
# +------+---------------+----------+---------+--------------+-----------+----------------+-----------+-------------+--------------------+--------------+-------+---------------+---------------+------------+--------------------+--------+--------+--------+-------+---------------------+
# only showing top 20 rows

# %%
df = df.withColumn("Amount of discount",df['Orginal Value of Sale'] - df['Sales'])
df.select("Sales","Amount of discount").show()
# Out:
# +--------+------------------+
# |   Sales|Amount of discount|
# +--------+------------------+
# |    79.2|               0.0|
# |  388.92|               0.0|
# |   35.19|               0.0|
# |   50.94|               0.0|
# |  307.44|               0.0|
# |   122.4|               0.0|
# |  413.82|               0.0|
# |  428.22|               0.0|
# | 3979.29|               0.0|
# |   43.56|               0.0|
# |   25.26|               0.0|
# |2443.905|              null|
# |   12.21|               0.0|
# |2167.296|              null|
# | 138.105|              null|
# | 128.385|              null|
# |  690.12|               0.0|
# |    8.16|               0.0|
# |  347.88|               0.0|
# | 575.505|              null|
# +--------+------------------+
# only showing top 20 rows

# %%
count_of_gain = df.groupBy("Discount").agg({'Amount of discount': 'sum'})
count_of_gain.show()
# Out:
# +--------+-----------------------+
# |Discount|sum(Amount of discount)|
# +--------+-----------------------+
# |    null|                   null|
# |       0|                    0.0|
# +--------+-----------------------+

# %%
count_of_gain = df.groupBy("Discount").agg({'Amount of discount': 'sum'}).orderBy("sum(Amount of discount)",ascending =False)
count_of_gain.show()
# Out:
# +--------+-----------------------+
# |Discount|sum(Amount of discount)|
# +--------+-----------------------+
# |       0|                    0.0|
# |    null|                   null|
# +--------+-----------------------+

# %%
df.select(sum("Profit")+sum("Amount of discount")).show()
# Out:
# +---------------------------------------+
# |(sum(Profit) + sum(Amount of discount))|
# +---------------------------------------+
# |                      372829.7414190746|
# +---------------------------------------+

# %%
df.select((sum("Profit")+sum("Amount of discount"))-sum("Profit")).show()
# Out:
# +-------------------------------------------------------+
# |((sum(Profit) + sum(Amount of discount)) - sum(Profit))|
# +-------------------------------------------------------+
# |                                                    0.0|
# +-------------------------------------------------------+

# %%
df.createOrReplaceTempView("superstore")

# %%
spark.sql("SELECT Country , SUM(Profit)/SUM(Sales) AS profit_ratio FROM superstore GROUP BY Country").show()
# Out:
# +--------------+-------------------+
# |       Country|       profit_ratio|
# +--------------+-------------------+
# |        Sweden|-0.5745674277080725|
# |       Germany|0.17066792085089796|
# |        France|0.12693568250632956|
# |       Belgium|0.23508766322655358|
# |       Finland| 0.1886429656028743|
# |         Italy|0.06844355261600243|
# |        Norway| 0.2517747558357422|
# |         Spain|0.18941580526198554|
# |       Denmark| -0.495719004670541|
# |       Ireland|-0.4442667746327458|
# |   Switzerland|0.29092012336571044|
# |      Portugal| -0.576166236329489|
# |       Austria|0.26419087935813323|
# |United Kingdom|0.21170103628484374|
# |   Netherlands|-0.5298342848078443|
# +--------------+-------------------+

# %%
spark.sql("SELECT Country, SUM(Profit) , SUM(Profit)/SUM(Sales) AS profit_ratio FROM superstore GROUP BY Country ORDER BY SUM(Profit) DESC ").show()
# Out:
# +--------------+-------------------+-------------------+
# |       Country|        sum(Profit)|       profit_ratio|
# +--------------+-------------------+-------------------+
# |United Kingdom| 111900.15013868175|0.21170103628484374|
# |        France| 109029.00298916548|0.12693568250632956|
# |       Germany| 107322.82054615906|0.17066792085089796|
# |         Spain|  54390.11980030127|0.18941580526198554|
# |       Austria| 21442.259948462248|0.26419087935813323|
# |         Italy| 19828.758236613125|0.06844355261600243|
# |       Belgium| 11572.589964687824|0.23508766322655358|
# |   Switzerland| 7237.4700926840305|0.29092012336571044|
# |        Norway|  5167.770015597343| 0.2517747558357422|
# |       Finland|  3905.729992687702| 0.1886429656028743|
# |       Denmark| -4282.047019600868| -0.495719004670541|
# |       Ireland| -7392.381024058908|-0.4442667746327458|
# |      Portugal| -8703.060049800202| -0.576166236329489|
# |        Sweden|-17519.367032960057|-0.5745674277080725|
# |   Netherlands| -41070.07517954521|-0.5298342848078443|
# +--------------+-------------------+-------------------+
